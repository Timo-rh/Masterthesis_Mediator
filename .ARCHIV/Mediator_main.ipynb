# %%
from langchain.chat_models import init_chat_model

# LLMs initalisieren
claude = init_chat_model("claude-instant-1.2", model_kwargs={"temperature": 0})


output = llm.invoke("Hi")
print(output)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 from langchain_anthropic import ChatAnthropic
#       3 llm = ChatAnthropic(model="claude-3-5-sonnet-latest")
# ----> 5 output = llm.invoke("Hi")
#       6 print(output)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\chat_models.py:371, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     359 @override
#     360 def invoke(
#     361     self,
#    (...)
#     366     **kwargs: Any,
#     367 ) -> BaseMessage:
#     368     config = ensure_config(config)
#     369     return cast(
#     370         "ChatGeneration",
# --> 371         self.generate_prompt(
#     372             [self._convert_input(input)],
#     373             stop=stop,
#     374             callbacks=config.get("callbacks"),
# ...

# %%
import pddl.logic
print(dir(pddl.logic))
# Out:
# ['Constant', 'Predicate', 'Variable', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'base', 'constants', 'effects', 'functions', 'helpers', 'predicates', 'terms', 'variables']

# %%
import sys
print(sys.path)
# Out:
# ['C:\\Users\\timor\\PycharmProjects\\Masterthesis_Mediator', 'C:\\Program Files\\JetBrains\\PyCharm 2023.3.2\\plugins\\python-ce\\helpers\\pydev', 'C:\\Program Files\\JetBrains\\PyCharm 2023.3.2\\plugins\\python-ce\\helpers\\jupyter_debug', 'C:\\Users\\timor\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\timor\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'C:\\Users\\timor\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'C:\\Users\\timor\\AppData\\Local\\Programs\\Python\\Python313', 'C:\\Users\\timor\\PycharmProjects\\Masterthesis_Mediator\\.venv', '', 'C:\\Users\\timor\\PycharmProjects\\Masterthesis_Mediator\\.venv\\Lib\\site-packages', '__editable__.mediator-0.0.1.finder.__path_hook__', 'C:\\Users\\timor\\PycharmProjects\\Masterthesis_Mediator\\.venv\\Lib\\site-packages\\win32', 'C:\\Users\\timor\\PycharmProjects\\Masterthesis_Mediator\\.venv\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\timor\\PycharmProjects\\Masterthesis_Mediator\\.venv\\Li
# ...
